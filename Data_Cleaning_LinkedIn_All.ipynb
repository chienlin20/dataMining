# %%
# library here
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
# read data and concat them
df_ds = pd.read_csv("/content/LinedIn_Data_scientists.csv")
df_an = pd.read_csv("/content/LinedIn_Data_Analysts.csv")
df_de = pd.read_csv("/content/LinedIn_Data_Engineer.csv")

df = pd.concat([df_ds, df_an, df_de], ignore_index=True, axis=0)

# %%
# check the info of data without preprocessing
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7123 entries, 0 to 7122
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_title        7120 non-null   object
#  1   company_name     7120 non-null   object
#  2   time_posted      6627 non-null   object
#  3   num_applicants   2572 non-null   object
#  4   salary           2032 non-null   object
#  5   location         7120 non-null   object
#  6   description      7120 non-null   object
#  7   Seniority level  7120 non-null   object
#  8   Employment type  7120 non-null   object
#  9   Job function     7120 non-null   object
#  10  Industries       7120 non-null   object
# dtypes: object(11)
# memory usage: 612.3+ KB

# %%
# check the # of duplicated and delete them
print(df.duplicated().sum())
df = df.drop_duplicates().reset_index(drop=True)
# Out:
# 6424

# %%
# info of dataset after removing duplicates
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_title        698 non-null    object
#  1   company_name     698 non-null    object
#  2   time_posted      643 non-null    object
#  3   num_applicants   266 non-null    object
#  4   salary           207 non-null    object
#  5   location         698 non-null    object
#  6   description      698 non-null    object
#  7   Seniority level  698 non-null    object
#  8   Employment type  698 non-null    object
#  9   Job function     698 non-null    object
#  10  Industries       698 non-null    object
# dtypes: object(11)
# memory usage: 60.2+ KB

# %%
# create new column "Number of duplicates"
# after fill all null values
# df["Num of duplicates"] = df.groupby(df.columns.to_list()).transform('size')-1
# df

# %% [markdown]
# ## location

# %%
# split "location" column into "city" and "state" columns
df[["city", "state"]] = df["location"].str.split(",", expand=True)
df.loc[df["city"]=="Remote", "state"] = "Remote"
df.loc[df["city"]=="United States", "state"] = "United States"
df.drop(columns=["location"], inplace=True)
df.head()

# df["city"].unique()
# Out:
#                         job_title      company_name   time_posted  \
# 0                 Data Scientists           Further   1 month ago
# 1          Data Scientist(Junior)     SynergisticIT  5 months ago
# 2  Junior Data Scientist - Remote     SynergisticIT  5 months ago
# 3                Data Scientist I  ConstructConnect    1 week ago
# 4          Data Scientist(Remote)     SynergisticIT  5 months ago
#
#    num_applicants salary                                        description  \
# 0  155 applicants    NaN  If you love data and are looking for unlimited...
# 1   31 applicants    NaN  At SynergisticIT, we aim to bring aboard IT pr...
# 2             NaN    NaN  Since 2010 Synergisticit has helped Jobseekers...
# 3             NaN    NaN  This position sits within our Product Developm...
# 4             NaN    NaN  Synergistic IT is a full-service staffing and ...
#
#   Seniority level Employment type                            Job function  \
# 0     Entry level       Full-time  Engineering and Information Technology
# 1     Entry level       Part-time  Engineering and Information Technology
# 2     Entry level       Full-time  Engineering and Information Technology
# 3     Entry level       Full-time  Engineering and Information Technology
# 4     Entry level       Full-time  Engineering and Information Technology
#
#                          Industries        city           state
# 0  Business Consulting and Services   Cleveland              OH
# 1     IT Services and IT Consulting        Ohio   United States
# 2     IT Services and IT Consulting    Columbus              OH
# 3              Software Development  Cincinnati              OH
# 4     IT Services and IT Consulting    Columbus              OH

# %%
df.dropna(subset=["job_title"], inplace=True)

# %% [markdown]
# ## time posted

# %%
# function of unifying the units
def adjust_time_posted(x):
  if pd.notna(x):
    time_posted = x.split()
    num = int(time_posted[0])
    unit = time_posted[1]
    if "year" in unit:
      return num*365
    elif "month" in unit:
      return num*30
    elif "week" in unit:
      return num*7
    elif "day" in unit:
      return num
    else:
      return np.nan

# %%
# apply the adjust_time_posted function to "time posted" column
df["adjusted time_posted"] = df["time_posted"].apply(adjust_time_posted)

# remove "time posted" column
df.drop("time_posted", axis=1, inplace=True)
# If the values in adjusted time posted are null, fill them with the mean
df["adjusted time_posted"] = df["adjusted time_posted"].fillna(df["adjusted time_posted"].mean())

# %% [markdown]
# ## num applicants

# %%
# conver data type from obj to numeric
df["num_applicants"] = df["num_applicants"].str.replace("applicants", "").astype(float)
df.head()
# Out:
#                         job_title      company_name  num_applicants salary  \
# 0                 Data Scientists           Further           155.0    NaN
# 1          Data Scientist(Junior)     SynergisticIT            31.0    NaN
# 2  Junior Data Scientist - Remote     SynergisticIT             NaN    NaN
# 3                Data Scientist I  ConstructConnect             NaN    NaN
# 4          Data Scientist(Remote)     SynergisticIT             NaN    NaN
#
#                                          description Seniority level  \
# 0  If you love data and are looking for unlimited...     Entry level
# 1  At SynergisticIT, we aim to bring aboard IT pr...     Entry level
# 2  Since 2010 Synergisticit has helped Jobseekers...     Entry level
# 3  This position sits within our Product Developm...     Entry level
# 4  Synergistic IT is a full-service staffing and ...     Entry level
#
#   Employment type                            Job function  \
# 0       Full-time  Engineering and Information Technology
# 1       Part-time  Engineering and Information Technology
# 2       Full-time  Engineering and Information Technology
# 3       Full-time  Engineering and Information Technology
# 4       Full-time  Engineering and Information Technology
#
#                          Industries        city           state  \
# 0  Business Consulting and Services   Cleveland              OH
# 1     IT Services and IT Consulting        Ohio   United States
# 2     IT Services and IT Consulting    Columbus              OH
# 3              Software Development  Cincinnati              OH
# 4     IT Services and IT Consulting    Columbus              OH
#
#    adjusted time_posted
# 0                  30.0
# 1                 150.0
# 2                 150.0
# 3                   7.0
# 4                 150.0

# %% [markdown]
# ## salary column

# %%
# function to unify the unit
def adjust_salary(x):
    if pd.notna(x): # Not null
        if x < 1000:
            return x * 1767
        else:
            return x
    return x

# %%
df["salary"].unique()
df["salary"] = df["salary"].str.replace("/yr", "")
df["salary"] = df["salary"].str.replace("/hr", "")
df["salary"] = df["salary"].str.replace("₹", "")
df["salary"] = df["salary"].str.replace("$", "")
df["salary"] = df["salary"].str.replace(",", "")
# df["salary"].unique()
df[["min salary", "max salary"]] = df["salary"].str.split("-", expand=True)
df["min salary"] = pd.to_numeric(df["min salary"])
df["max salary"] = pd.to_numeric(df["max salary"])
df["min salary"] = df["min salary"].apply(adjust_salary)
df["max salary"] = df["max salary"].apply(adjust_salary)
df.drop(columns=["salary"], axis=1, inplace=True)
df
# Out:
#                                          job_title               company_name  \
# 0                                  Data Scientists                    Further
# 1                           Data Scientist(Junior)              SynergisticIT
# 2                   Junior Data Scientist - Remote              SynergisticIT
# 3                                 Data Scientist I           ConstructConnect
# 4                           Data Scientist(Remote)              SynergisticIT
# ..                                             ...                        ...
# 694           Power BI Dashboard Analyst Developer  Tata Consultancy Services
# 695                Software Engineer Opportunities          Central Insurance
# 696  Software Quality Assurance (QA) Test Engineer                    Medpace
# 697                           Software Engineer II                  Honeywell
# 698                       Senior Software Engineer            Kaiser Aluminum
#
#      num_applicants                                        description  \
# 0             155.0  If you love data and are looking for unlimited...
# 1              31.0  At SynergisticIT, we aim to bring aboard IT pr...
# 2               NaN  Since 2010 Synergisticit has helped Jobseekers...
# 3               NaN  This position sits within our Product Developm...
# 4               NaN  Synergistic IT is a full-service staffing and ...
# ..              ...                                                ...
# 694             NaN  Technical/Functional Skills Power BI Dashboard...
# 695             NaN  Location: Hybrid Work Model – Van Wert, Ohio o...
# 696             NaN  Voted a Top Cincinnati Workplace for 4 years r...
# 697             NaN  Join a team recognized for leadership, innovat...
# 698            32.0  Industry 4.0 Senior Software Engineer – Newark...
#
#       Seniority level Employment type  \
# 0         Entry level       Full-time
# 1         Entry level       Part-time
# 2         Entry level       Full-time
# 3         Entry level       Full-time
# 4         Entry level       Full-time
# ..                ...             ...
# 694  Mid-Senior level       Full-time
# 695       Entry level       Full-time
# 696    Not Applicable       Full-time
# 697       Entry level       Full-time
# 698  Mid-Senior level       Full-time
#
#                                           Job function  \
# 0               Engineering and Information Technology
# 1               Engineering and Information Technology
# 2               Engineering and Information Technology
# 3               Engineering and Information Technology
# 4               Engineering and Information Technology
# ..                                                 ...
# 694      Research, Analyst, and Information Technology
# 695             Engineering and Information Technology
# 696                                  Quality Assurance
# 697             Engineering and Information Technology
# 698  Manufacturing, Production, and Project Management
#
#                                             Industries        city  \
# 0                     Business Consulting and Services   Cleveland
# 1                        IT Services and IT Consulting        Ohio
# 2                        IT Services and IT Consulting    Columbus
# 3                                 Software Development  Cincinnati
# 4                        IT Services and IT Consulting    Columbus
# ..                                                 ...         ...
# 694                      IT Services and IT Consulting    Columbus
# 695                                          Insurance    Van Wert
# 696                       Pharmaceutical Manufacturing  Cincinnati
# 697  Appliances, Electrical, and Electronics Manufa...       Mason
# 698  Primary Metal Manufacturing and Fabricated Met...      Newark
#
#               state  adjusted time_posted  min salary  max salary
# 0                OH             30.000000         NaN         NaN
# 1     United States            150.000000         NaN         NaN
# 2                OH            150.000000         NaN         NaN
# 3                OH              7.000000         NaN         NaN
# 4                OH            150.000000         NaN         NaN
# ..              ...                   ...         ...         ...
# 694              OH              7.000000     95000.0    120000.0
# 695              OH              7.000000         NaN         NaN
# 696              OH             32.267496         NaN         NaN
# 697              OH             14.000000         NaN         NaN
# 698              OH              7.000000         NaN         NaN
#
# [698 rows x 13 columns]

# %%
# check the # of null
df.isna().sum()
# Out:
# job_title                 0
# company_name              0
# num_applicants          432
# description               0
# Seniority level           0
# Employment type           0
# Job function              0
# Industries                0
# city                      0
# state                    15
# adjusted time_posted      0
# min salary              491
# max salary              491
# dtype: int64

# %%
# fill the null values with the mean
df["num_applicants"] = df["num_applicants"].fillna(df["num_applicants"].mean())

# %%
# fill the null values with "Other"
df["city"] = df["city"].fillna("Other")
df["state"] = df["state"].fillna("Other")

# %%
# fill the null values with the mean
df["adjusted time_posted"] = df["adjusted time_posted"].fillna(df["adjusted time_posted"].mean())

# %%
# fill the null values depending on the city and Industries
# calculate the min & max salry depending on the city and Industries
avg_min_salary_per_city_industry = df.groupby(["city", "Industries"])["min salary"].mean()
avg_max_salary_per_city_industry = df.groupby(["city", "Industries"])["max salary"].mean()

# fill the null values
df["min salary"] = df.apply(
  # get the avg min salary based on "city" and "Industries"
  lambda x: avg_min_salary_per_city_industry.get((x["city"], x["Industries"]), x["min salary"])
  # if "min salary" is null, replace it with the avg min salary
  if pd.isna(x["min salary"]) else x["min salary"], axis=1
)

df["max salary"] = df.apply(
  # get the avg max salary based on "city" and "Industries"
  lambda x: avg_max_salary_per_city_industry.get((x["city"], x["Industries"]), x["max salary"])
  # if "max salary" is null, replace it with the avg max salary
  if pd.isna(x["max salary"]) else x["max salary"], axis=1
)

# %%
# if the null values are not replaced, fill them with the median
df["min salary"] = df["min salary"].fillna(df["min salary"].median())
df["max salary"] = df["max salary"].fillna(df["max salary"].median())

# %%
df
# Out:
#                                          job_title               company_name  \
# 0                                  Data Scientists                    Further
# 1                           Data Scientist(Junior)              SynergisticIT
# 2                   Junior Data Scientist - Remote              SynergisticIT
# 3                                 Data Scientist I           ConstructConnect
# 4                           Data Scientist(Remote)              SynergisticIT
# ..                                             ...                        ...
# 694           Power BI Dashboard Analyst Developer  Tata Consultancy Services
# 695                Software Engineer Opportunities          Central Insurance
# 696  Software Quality Assurance (QA) Test Engineer                    Medpace
# 697                           Software Engineer II                  Honeywell
# 698                       Senior Software Engineer            Kaiser Aluminum
#
#      num_applicants                                        description  \
# 0        155.000000  If you love data and are looking for unlimited...
# 1         31.000000  At SynergisticIT, we aim to bring aboard IT pr...
# 2         85.699248  Since 2010 Synergisticit has helped Jobseekers...
# 3         85.699248  This position sits within our Product Developm...
# 4         85.699248  Synergistic IT is a full-service staffing and ...
# ..              ...                                                ...
# 694       85.699248  Technical/Functional Skills Power BI Dashboard...
# 695       85.699248  Location: Hybrid Work Model – Van Wert, Ohio o...
# 696       85.699248  Voted a Top Cincinnati Workplace for 4 years r...
# 697       85.699248  Join a team recognized for leadership, innovat...
# 698       32.000000  Industry 4.0 Senior Software Engineer – Newark...
#
#       Seniority level Employment type  \
# 0         Entry level       Full-time
# 1         Entry level       Part-time
# 2         Entry level       Full-time
# 3         Entry level       Full-time
# 4         Entry level       Full-time
# ..                ...             ...
# 694  Mid-Senior level       Full-time
# 695       Entry level       Full-time
# 696    Not Applicable       Full-time
# 697       Entry level       Full-time
# 698  Mid-Senior level       Full-time
#
#                                           Job function  \
# 0               Engineering and Information Technology
# 1               Engineering and Information Technology
# 2               Engineering and Information Technology
# 3               Engineering and Information Technology
# 4               Engineering and Information Technology
# ..                                                 ...
# 694      Research, Analyst, and Information Technology
# 695             Engineering and Information Technology
# 696                                  Quality Assurance
# 697             Engineering and Information Technology
# 698  Manufacturing, Production, and Project Management
#
#                                             Industries        city  \
# 0                     Business Consulting and Services   Cleveland
# 1                        IT Services and IT Consulting        Ohio
# 2                        IT Services and IT Consulting    Columbus
# 3                                 Software Development  Cincinnati
# 4                        IT Services and IT Consulting    Columbus
# ..                                                 ...         ...
# 694                      IT Services and IT Consulting    Columbus
# 695                                          Insurance    Van Wert
# 696                       Pharmaceutical Manufacturing  Cincinnati
# 697  Appliances, Electrical, and Electronics Manufa...       Mason
# 698  Primary Metal Manufacturing and Fabricated Met...      Newark
#
#               state  adjusted time_posted     min salary     max salary
# 0                OH             30.000000   92500.000000  100000.000000
# 1     United States            150.000000  103327.000000  182983.000000
# 2                OH            150.000000  100977.222222  126081.444444
# 3                OH              7.000000   80975.333333  129623.666667
# 4                OH            150.000000  100977.222222  126081.444444
# ..              ...                   ...            ...            ...
# 694              OH              7.000000   95000.000000  120000.000000
# 695              OH              7.000000  100977.222222  126081.444444
# 696              OH             32.267496  100977.222222  126081.444444
# 697              OH             14.000000  100977.222222  126081.444444
# 698              OH              7.000000  100977.222222  126081.444444
#
# [698 rows x 13 columns]

# %%
# check the # of null values
df.isna().sum()
# Out:
# job_title               0
# company_name            0
# num_applicants          0
# description             0
# Seniority level         0
# Employment type         0
# Job function            0
# Industries              0
# city                    0
# state                   0
# adjusted time_posted    0
# min salary              0
# max salary              0
# dtype: int64

# %%
#output the dataframe
df.to_csv("LinkedIn_cleaned_data.csv", index=False)
